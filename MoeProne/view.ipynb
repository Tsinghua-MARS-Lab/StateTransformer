# %%
import pickle

# 假设 'example.pkl' 是你的 pickle 文件的路径
filename = '/cephfs/zhanjh/experiment/moe_prone/generated_predictions.pickle'

# 使用 'rb' 模式打开文件，因为 pickle 文件是二进制格式
with open(filename, 'rb') as file:
    # 加载 pickle 文件中的对象
    data = pickle.load(file)

# %%
import sys
sys.path.append('/cephfs/zhanjh/STR/StateTransformer')
from transformer4planning.trainer import save_raster

# %%
data["predicted_trajectory"][1]["key_points_logits"]
# Out:
# tensor([[[ 7.7592e+01,  5.6546e+00],
#          [ 3.8994e+01,  1.7812e+00],
#          [ 1.9748e+01,  5.9404e-01],
#          [ 1.0128e+01,  1.6280e-01],
#          [ 5.2431e+00, -2.5513e-03]],
#
#         [[ 7.7649e+01,  5.8077e+00],
#          [ 3.9004e+01,  1.8469e+00],
#          [ 1.9747e+01,  6.1825e-01],
#          [ 1.0127e+01,  1.7197e-01],
#          [ 5.2417e+00,  1.0923e-03]],
#
#         [[ 7.7625e+01,  5.8620e+00],
#          [ 3.8996e+01,  1.8715e+00],
#          [ 1.9745e+01,  6.2753e-01],
#          [ 1.0126e+01,  1.7556e-01],
#          [ 5.2412e+00,  2.5589e-03]],
#
#         [[ 7.7624e+01,  5.8624e+00],
#          [ 3.8996e+01,  1.8717e+00],
#          [ 1.9745e+01,  6.2761e-01],
#          [ 1.0126e+01,  1.7559e-01],
#          [ 5.2412e+00,  2.5735e-03]],
#
#         [[ 7.7624e+01,  5.8602e+00],
#          [ 3.8996e+01,  1.8708e+00],
#          [ 1.9745e+01,  6.2727e-01],
#          [ 1.0126e+01,  1.7546e-01],
#          [ 5.2412e+00,  2.5224e-03]],
#
#         [[ 7.7625e+01,  5.8624e+00],
#          [ 3.8996e+01,  1.8717e+00],
#          [ 1.9745e+01,  6.2761e-01],
#          [ 1.0126e+01,  1.7559e-01],
#          [ 5.2412e+00,  2.5722e-03]],
#
#         [[ 7.7626e+01,  5.8618e+00],
#          [ 3.8996e+01,  1.8714e+00],
#          [ 1.9745e+01,  6.2750e-01],
#          [ 1.0126e+01,  1.7554e-01],
#          [ 5.2412e+00,  2.5517e-03]],
#
#         [[ 7.7616e+01,  5.6004e+00],
#          [ 3.9002e+01,  1.7564e+00],
#          [ 1.9750e+01,  5.8458e-01],
#          [ 1.0129e+01,  1.5912e-01],
#          [ 5.2435e+00, -4.0685e-03]],
#
#         [[ 7.7592e+01,  5.6540e+00],
#          [ 3.8994e+01,  1.7809e+00],
#          [ 1.9748e+01,  5.9393e-01],
#          [ 1.0128e+01,  1.6276e-01],
#          [ 5.2431e+00, -2.5690e-03]],
#
#         [[ 7.7591e+01,  5.6544e+00],
#          [ 3.8994e+01,  1.7811e+00],
#          [ 1.9748e+01,  5.9402e-01],
#          [ 1.0128e+01,  1.6279e-01],
#          [ 5.2431e+00, -2.5541e-03]],
#
#         [[ 7.7591e+01,  5.6522e+00],
#          [ 3.8994e+01,  1.7801e+00],
#          [ 1.9748e+01,  5.9366e-01],
#          [ 1.0128e+01,  1.6266e-01],
#          [ 5.2431e+00, -2.6083e-03]],
#
#         [[ 7.7592e+01,  5.6545e+00],
#          [ 3.8994e+01,  1.7811e+00],
#          [ 1.9748e+01,  5.9401e-01],
#          [ 1.0128e+01,  1.6279e-01],
#          [ 5.2431e+00, -2.5549e-03]],
#
#         [[ 7.7593e+01,  5.6539e+00],
#          [ 3.8994e+01,  1.7808e+00],
#          [ 1.9748e+01,  5.9389e-01],
#          [ 1.0128e+01,  1.6274e-01],
#          [ 5.2431e+00, -2.5755e-03]],
#
#         [[ 7.7650e+01,  5.8072e+00],
#          [ 3.9004e+01,  1.8467e+00],
#          [ 1.9748e+01,  6.1815e-01],
#          [ 1.0127e+01,  1.7193e-01],
#          [ 5.2417e+00,  1.0749e-03]],
#
#         [[ 7.7649e+01,  5.8075e+00],
#          [ 3.9003e+01,  1.8469e+00],
#          [ 1.9747e+01,  6.1823e-01],
#          [ 1.0127e+01,  1.7196e-01],
#          [ 5.2417e+00,  1.0902e-03]],
#
#         [[ 7.7648e+01,  5.8054e+00],
#          [ 3.9003e+01,  1.8460e+00],
#          [ 1.9747e+01,  6.1789e-01],
#          [ 1.0127e+01,  1.7183e-01],
#          [ 5.2417e+00,  1.0387e-03]],
#
#         [[ 7.7649e+01,  5.8076e+00],
#          [ 3.9004e+01,  1.8469e+00],
#          [ 1.9747e+01,  6.1823e-01],
#          [ 1.0127e+01,  1.7196e-01],
#          [ 5.2417e+00,  1.0891e-03]],
#
#         [[ 7.7650e+01,  5.8070e+00],
#          [ 3.9004e+01,  1.8466e+00],
#          [ 1.9748e+01,  6.1811e-01],
#          [ 1.0127e+01,  1.7192e-01],
#          [ 5.2417e+00,  1.0690e-03]],
#
#         [[ 7.7625e+01,  5.8618e+00],
#          [ 3.8996e+01,  1.8715e+00],
#          [ 1.9745e+01,  6.2751e-01],
#          [ 1.0126e+01,  1.7555e-01],
#          [ 5.2412e+00,  2.5562e-03]],
#
#         [[ 7.7624e+01,  5.8597e+00],
#          [ 3.8996e+01,  1.8705e+00],
#          [ 1.9745e+01,  6.2717e-01],
#          [ 1.0126e+01,  1.7542e-01],
#          [ 5.2412e+00,  2.5055e-03]],
#
#         [[ 7.7625e+01,  5.8619e+00],
#          [ 3.8996e+01,  1.8715e+00],
#          [ 1.9745e+01,  6.2751e-01],
#          [ 1.0126e+01,  1.7555e-01],
#          [ 5.2412e+00,  2.5553e-03]],
#
#         [[ 7.7627e+01,  5.8613e+00],
#          [ 3.8997e+01,  1.8712e+00],
#          [ 1.9745e+01,  6.2739e-01],
#          [ 1.0126e+01,  1.7550e-01],
#          [ 5.2412e+00,  2.5355e-03]],
#
#         [[ 7.7623e+01,  5.8601e+00],
#          [ 3.8996e+01,  1.8707e+00],
#          [ 1.9745e+01,  6.2725e-01],
#          [ 1.0126e+01,  1.7545e-01],
#          [ 5.2412e+00,  2.5199e-03]],
#
#         [[ 7.7624e+01,  5.8623e+00],
#          [ 3.8996e+01,  1.8717e+00],
#          [ 1.9745e+01,  6.2759e-01],
#          [ 1.0126e+01,  1.7558e-01],
#          [ 5.2412e+00,  2.5698e-03]],
#
#         [[ 7.7626e+01,  5.8617e+00],
#          [ 3.8996e+01,  1.8714e+00],
#          [ 1.9745e+01,  6.2748e-01],
#          [ 1.0126e+01,  1.7553e-01],
#          [ 5.2412e+00,  2.5495e-03]],
#
#         [[ 7.7624e+01,  5.8601e+00],
#          [ 3.8996e+01,  1.8707e+00],
#          [ 1.9745e+01,  6.2725e-01],
#          [ 1.0126e+01,  1.7545e-01],
#          [ 5.2412e+00,  2.5191e-03]],
#
#         [[ 7.7625e+01,  5.8595e+00],
#          [ 3.8996e+01,  1.8704e+00],
#          [ 1.9745e+01,  6.2713e-01],
#          [ 1.0126e+01,  1.7540e-01],
#          [ 5.2412e+00,  2.4984e-03]],
#
#         [[ 7.7626e+01,  5.8617e+00],
#          [ 3.8996e+01,  1.8714e+00],
#          [ 1.9745e+01,  6.2747e-01],
#          [ 1.0126e+01,  1.7553e-01],
#          [ 5.2412e+00,  2.5482e-03]]], device='cuda:0')

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
j=19
for i in range(28):
    image_dictionary = save_raster(inputs=data["input"][j],
                                sample_index=0,
                                file_index=i,
                                high_scale=1,
                                prediction_trajectory=data["predicted_trajectory"][j]["traj_logits"][i],
                                prediction_key_point_by_gen=data["predicted_trajectory"][j]["key_points_logits"][i],
                                path_to_save="/cephfs/zhanjh/experiment/moe_prone/image")


# 设置图像显示的大小
plt.figure(figsize=(20, 40))  # 宽度20英寸，高度40英寸，根据需要调整

# 循环遍历所有图像编号
for i in range(28):
    img_path = f"/cephfs/zhanjh/experiment/moe_prone/image/test_{i}_0_high_res_raster.png"
    img = mpimg.imread(img_path)  # 加载图像
    plt.subplot(7, 4, i + 1)  # 7行4列的布局
    plt.imshow(img)  # 显示图像
    plt.axis('off')  # 隐藏坐标轴

plt.tight_layout()  # 调整子图间距
plt.show()  # 显示所有图像
# Out:
# length of action and labels:  torch.Size([4, 7])
# debug images saved to:  /cephfs/zhanjh/experiment/moe_prone/image 0
# length of action and labels:  torch.Size([4, 7])
# debug images saved to:  /cephfs/zhanjh/experiment/moe_prone/image 1
# length of action and labels:  torch.Size([4, 7])
# debug images saved to:  /cephfs/zhanjh/experiment/moe_prone/image 2
# length of action and labels:  torch.Size([4, 7])
# debug images saved to:  /cephfs/zhanjh/experiment/moe_prone/image 3
# length of action and labels:  torch.Size([4, 7])
# debug images saved to:  /cephfs/zhanjh/experiment/moe_prone/image 4
# length of action and labels:  torch.Size([4, 7])
# debug images saved to:  /cephfs/zhanjh/experiment/moe_prone/image 5
# length of action and labels:  torch.Size([4, 7])
# debug images saved to:  /cephfs/zhanjh/experiment/moe_prone/image 6
# length of action and labels:  torch.Size([4, 7])
# debug images saved to:  /cephfs/zhanjh/experiment/moe_prone/image 7
# length of action and labels:  torch.Size([4, 7])
# debug images saved to:  /cephfs/zhanjh/experiment/moe_prone/image 8
# length of action and labels:  torch.Size([4, 7])
# debug images saved to:  /cephfs/zhanjh/experiment/moe_prone/image 9
# length of action and labels:  torch.Size([4, 7])
# debug images saved to:  /cephfs/zhanjh/experiment/moe_prone/image 10
# length of action and labels:  torch.Size([4, 7])
# debug images saved to:  /cephfs/zhanjh/experiment/moe_prone/image 11
# length of action and labels:  torch.Size([4, 7])
# debug images saved to:  /cephfs/zhanjh/experiment/moe_prone/image 12
# length of action and labels:  torch.Size([4, 7])
# debug images saved to:  /cephfs/zhanjh/experiment/moe_prone/image 13
# length of action and labels:  torch.Size([4, 7])
# debug images saved to:  /cephfs/zhanjh/experiment/moe_prone/image 14
# length of action and labels:  torch.Size([4, 7])
# debug images saved to:  /cephfs/zhanjh/experiment/moe_prone/image 15
# length of action and labels:  torch.Size([4, 7])
# debug images saved to:  /cephfs/zhanjh/experiment/moe_prone/image 16
# length of action and labels:  torch.Size([4, 7])
# debug images saved to:  /cephfs/zhanjh/experiment/moe_prone/image 17
# length of action and labels:  torch.Size([4, 7])
# debug images saved to:  /cephfs/zhanjh/experiment/moe_prone/image 18
# length of action and labels:  torch.Size([4, 7])
# debug images saved to:  /cephfs/zhanjh/experiment/moe_prone/image 19
# length of action and labels:  torch.Size([4, 7])
# debug images saved to:  /cephfs/zhanjh/experiment/moe_prone/image 20
# length of action and labels:  torch.Size([4, 7])
# debug images saved to:  /cephfs/zhanjh/experiment/moe_prone/image 21
# length of action and labels:  torch.Size([4, 7])
# debug images saved to:  /cephfs/zhanjh/experiment/moe_prone/image 22
# length of action and labels:  torch.Size([4, 7])
# debug images saved to:  /cephfs/zhanjh/experiment/moe_prone/image 23
# length of action and labels:  torch.Size([4, 7])
# debug images saved to:  /cephfs/zhanjh/experiment/moe_prone/image 24
# length of action and labels:  torch.Size([4, 7])
# debug images saved to:  /cephfs/zhanjh/experiment/moe_prone/image 25
# length of action and labels:  torch.Size([4, 7])
# debug images saved to:  /cephfs/zhanjh/experiment/moe_prone/image 26
# length of action and labels:  torch.Size([4, 7])
# debug images saved to:  /cephfs/zhanjh/experiment/moe_prone/image 27
